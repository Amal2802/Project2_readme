# %% [markdown]
# <a href="https://colab.research.google.com/github/Amal2802/Project2_readme/blob/main/Project2_part1_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
#Import
import pandas as pd
import numpy as np

# %%
# Load in the data
df = pd.read_csv('/content/Car_Insurance_Claim.csv.zip')
# Take a look at the dataframe
df
# Out:
#           ID    AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION  \
# 0     569520    65+  female  majority               0-9y  high school
# 1     750365  16-25    male  majority               0-9y         none
# 2     199901  16-25  female  majority               0-9y  high school
# 3     478866  16-25    male  majority               0-9y   university
# 4     731664  26-39    male  majority             10-19y         none
# ...      ...    ...     ...       ...                ...          ...
# 9995  323164  26-39  female  majority             10-19y   university
# 9996  910346  26-39  female  majority             10-19y         none
# 9997  468409  26-39    male  majority               0-9y  high school
# 9998  903459  26-39  female  majority             10-19y  high school
# 9999  442696  26-39  female  majority               0-9y         none
#
#              INCOME  CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  \
# ...

# %%
# Look at the info from the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10000 non-null  int64
#  1   AGE                  10000 non-null  object
#  2   GENDER               10000 non-null  object
#  3   RACE                 10000 non-null  object
#  4   DRIVING_EXPERIENCE   10000 non-null  object
#  5   EDUCATION            10000 non-null  object
#  6   INCOME               10000 non-null  object
#  7   CREDIT_SCORE         9018 non-null   float64
#  8   VEHICLE_OWNERSHIP    10000 non-null  float64
#  9   VEHICLE_YEAR         10000 non-null  object
#  10  MARRIED              10000 non-null  float64
#  11  CHILDREN             10000 non-null  float64
#  12  POSTAL_CODE          10000 non-null  int64
#  13  ANNUAL_MILEAGE       9043 non-null   float64
#  14  VEHICLE_TYPE         10000 non-null  object
# ...

# %%
#duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
#check for missing values
print(df.isnull().sum())
# Out:
# ID                       0
# AGE                      0
# GENDER                   0
# RACE                     0
# DRIVING_EXPERIENCE       0
# EDUCATION                0
# INCOME                   0
# CREDIT_SCORE           982
# VEHICLE_OWNERSHIP        0
# VEHICLE_YEAR             0
# MARRIED                  0
# CHILDREN                 0
# POSTAL_CODE              0
# ANNUAL_MILEAGE         957
# VEHICLE_TYPE             0
# SPEEDING_VIOLATIONS      0
# DUIS                     0
# PAST_ACCIDENTS           0
# OUTCOME                  0
# dtype: int64

# %%
#replace missing values ​​with mean
df['ANNUAL_MILEAGE']=df['ANNUAL_MILEAGE'].fillna(df['ANNUAL_MILEAGE'].mean())
#replace missing values ​​with min
df['CREDIT_SCORE']=df['CREDIT_SCORE'].fillna(df['CREDIT_SCORE'].min())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10000 non-null  int64
#  1   AGE                  10000 non-null  object
#  2   GENDER               10000 non-null  object
#  3   RACE                 10000 non-null  object
#  4   DRIVING_EXPERIENCE   10000 non-null  object
#  5   EDUCATION            10000 non-null  object
#  6   INCOME               10000 non-null  object
#  7   CREDIT_SCORE         10000 non-null  float64
#  8   VEHICLE_OWNERSHIP    10000 non-null  float64
#  9   VEHICLE_YEAR         10000 non-null  object
#  10  MARRIED              10000 non-null  float64
#  11  CHILDREN             10000 non-null  float64
#  12  POSTAL_CODE          10000 non-null  int64
#  13  ANNUAL_MILEAGE       10000 non-null  float64
#  14  VEHICLE_TYPE         10000 non-null  object
# ...

# %%
#check for missing values
print(df.isnull().sum())
# Out:
# ID                     0
# AGE                    0
# GENDER                 0
# RACE                   0
# DRIVING_EXPERIENCE     0
# EDUCATION              0
# INCOME                 0
# CREDIT_SCORE           0
# VEHICLE_OWNERSHIP      0
# VEHICLE_YEAR           0
# MARRIED                0
# CHILDREN               0
# POSTAL_CODE            0
# ANNUAL_MILEAGE         0
# VEHICLE_TYPE           0
# SPEEDING_VIOLATIONS    0
# DUIS                   0
# PAST_ACCIDENTS         0
# OUTCOME                0
# dtype: int64

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['AGE']).mean()
# Out:
# <ipython-input-89-f1c5894d7dde>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['AGE']).mean()
#                   ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  CHILDREN  \
# AGE
# 16-25  492718.329365      0.370594           0.497024  0.203373  0.398313
# 26-39  498826.792034      0.442355           0.644793  0.412667  0.622592
# 40-64  506459.769362      0.511367           0.781303  0.612419  0.805186
# 65+    502290.888442      0.554336           0.855779  0.760302  0.913568
#
#         POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS      DUIS  \
# AGE
# 16-25  19776.849206    12810.203707             0.000000  0.000000
# 26-39  19390.412341    12008.066260             1.009468  0.172706
# 40-64  20470.613784    11223.145280             1.937564  0.324463
# ...

# %%
#rename categorical column
df.replace({'16-25': '1', '26-39': '2','40-64': '3','65+': '4'},inplace=True)
df['AGE'].value_counts()
# Out:
# 2    3063
# 3    2931
# 1    2016
# 4    1990
# Name: AGE, dtype: int64

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['GENDER']).mean()
# Out:
# <ipython-input-91-85d052503b89>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['GENDER']).mean()
#                    ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  CHILDREN  \
# GENDER
# female  502647.191816      0.479400           0.693613  0.494012  0.690020
# male    498388.103607      0.461363           0.700401  0.502405  0.687575
#
#          POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS      DUIS  \
# GENDER
# female  19902.232735    11737.304292             1.030739  0.187026
# male    19826.713026    11656.540594             1.936874  0.291583
#
#         PAST_ACCIDENTS   OUTCOME
# GENDER
# female        0.688224  0.263673
# male          1.425852  0.363126

# %%
#rename categorical column
df.replace({'female': '1', 'male': '2'},inplace=True)
df['GENDER'].value_counts()
# Out:
# 1    5010
# 2    4990
# Name: GENDER, dtype: int64

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['RACE']).mean()
# Out:
# <ipython-input-93-62c1234e744a>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['RACE']).mean()
#                      ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  CHILDREN  \
# RACE
# majority  501095.467821      0.471310           0.702286  0.501775  0.687639
# minority  495290.194332      0.462101           0.648785  0.465587  0.699393
#
#            POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS      DUIS  \
# RACE
# majority  19835.395251    11698.687839             1.493342  0.242011
# minority  20130.467611    11681.636903             1.387652  0.213563
#
#           PAST_ACCIDENTS   OUTCOME
# RACE
# majority        1.061141  0.312028
# minority        1.012146  0.324899

# %%
#rename categorical column
df.replace({'majority': '1', 'minority': '2'},inplace=True)
df['RACE'].value_counts()
# Out:
# 1    9012
# 2     988
# Name: RACE, dtype: int64

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['DRIVING_EXPERIENCE']).mean()
# Out:
# <ipython-input-95-d91421364511>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['DRIVING_EXPERIENCE']).mean()
#                                ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  \
# DRIVING_EXPERIENCE
# 0-9y                496940.238244      0.424487           0.591218  0.354674
# 10-19y              504158.957563      0.463619           0.694453  0.481661
# 20-29y              501271.497404      0.517664           0.798018  0.636149
# 30y+                499624.831749      0.550523           0.856464  0.753802
#
#                     CHILDREN   POSTAL_CODE  ANNUAL_MILEAGE  \
# DRIVING_EXPERIENCE
# 0-9y                0.545609  19701.781586    12192.354721
# 10-19y              0.680206  19694.941801    11782.159449
# ...

# %%
#rename categorical column
df.replace({'0-9y': '1', '10-19y': '2','20-29y': '3','30y+': '4'},inplace=True)
df['DRIVING_EXPERIENCE'].value_counts()
# Out:
# 1    3530
# 2    3299
# 3    2119
# 4    1052
# Name: DRIVING_EXPERIENCE, dtype: int64

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['EDUCATION']).mean()
# Out:
# <ipython-input-97-b6404d46fb47>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['EDUCATION']).mean()
#                         ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  \
# EDUCATION
# high school  503303.309358      0.463817           0.680779  0.480154
# none         500534.679896      0.376750           0.505483  0.329504
# university   497572.122963      0.523023           0.807536  0.599542
#
#              CHILDREN   POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  \
# EDUCATION
# high school  0.672841  19699.925427    11797.358495             1.406062
# none         0.595822  19285.278329    12220.891193             0.958225
# university   0.751018  20321.177699    11335.388536             1.820010
#
#                  DUIS  PAST_ACCIDENTS  OUTCOME
# EDUCATION
# ...

# %%
#rename categorical column
df.replace({'high school': '1', 'none': '2','university': '3'},inplace=True)
df['EDUCATION'].value_counts()
# Out:
# 1    4157
# 3    3928
# 2    1915
# Name: EDUCATION, dtype: int64

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['INCOME']).mean()
# Out:
# <ipython-input-99-b348a0b552c7>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['INCOME']).mean()
#                           ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  \
# INCOME
# middle class   505360.836296      0.477244           0.744153  0.481759
# poverty        498953.151047      0.318736           0.347299  0.200110
# upper class    499163.295895      0.562252           0.870618  0.701107
# working class  499582.087033      0.389915           0.568925  0.320678
#
#                CHILDREN   POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  \
# INCOME
# middle class   0.687091  19678.353134    11816.115851             1.367166
# poverty        0.471334  18960.982359    12709.284783             0.430540
# ...

# %%
#rename categorical column
df.replace({'middle class': '1', 'poverty': '2','upper class': '3','working class': '4'},inplace=True)
df['INCOME'].value_counts()
# Out:
# 3    4336
# 1    2138
# 2    1814
# 4    1712
# Name: INCOME, dtype: int64

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['VEHICLE_OWNERSHIP']).mean()
# Out:
# <ipython-input-101-3ff2d297bb8e>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['VEHICLE_OWNERSHIP']).mean()
#                               ID  CREDIT_SCORE   MARRIED  CHILDREN  \
# VEHICLE_OWNERSHIP
# 0.0                496476.566007      0.408643  0.365017   0.60033
# 1.0                502280.498278      0.497247  0.556098   0.72726
#
#                     POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  \
# VEHICLE_OWNERSHIP
# 0.0                20004.138944    12073.810533             1.027723
# 1.0                19803.865567    11533.197440             1.680775
#
#                        DUIS  PAST_ACCIDENTS   OUTCOME
# VEHICLE_OWNERSHIP
# 0.0                0.166337        0.756766  0.579868
# 1.0                0.270875        1.186514  0.197418

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['VEHICLE_YEAR']).mean()
# Out:
# <ipython-input-102-f790fb71e7c5>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['VEHICLE_YEAR']).mean()
#                          ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  \
# VEHICLE_YEAR
# after 2015    499079.594791      0.523719           0.807451  0.596439
# before 2015   501149.800057      0.447188           0.648916  0.455433
#
#               CHILDREN   POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  \
# VEHICLE_YEAR
# after 2015    0.762611  20064.014837    11397.589142             1.831850
# before 2015   0.656667  19777.713076    11827.349534             1.330989
#
#                   DUIS  PAST_ACCIDENTS   OUTCOME
# VEHICLE_YEAR
# after 2015    0.281240        1.300692  0.106495
# before 2015   0.220899        0.949907  0.403330

# %%
#rename categorical column
df.replace({'after 2015': '1', 'before 2015': '2'},inplace=True)
df['VEHICLE_YEAR'].value_counts()
# Out:
# 2    6967
# 1    3033
# Name: VEHICLE_YEAR, dtype: int64

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['MARRIED']).mean()
# Out:
# <ipython-input-104-a50df2c06417>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['MARRIED']).mean()
#                     ID  CREDIT_SCORE  VEHICLE_OWNERSHIP  CHILDREN  \
# MARRIED
# 0.0      496237.592069      0.433834           0.616580  0.556397
# 1.0      504837.180048      0.507230           0.778001  0.822160
#
#           POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS      DUIS  \
# MARRIED
# 0.0      19637.536867    12870.698990             0.994022  0.172379
# 1.0      20093.200321    10514.826282             1.975311  0.306503
#
#          PAST_ACCIDENTS   OUTCOME
# MARRIED
# 0.0            0.701873  0.434436
# 1.0            1.413288  0.191289

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['CHILDREN']).mean()
# Out:
# <ipython-input-105-42e7685a8b34>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['CHILDREN']).mean()
#                      ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  \
# CHILDREN
# 0.0       499990.107648      0.429437           0.610861  0.284704
# 1.0       500762.173780      0.488906           0.735918  0.594657
#
#            POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS      DUIS  \
# CHILDREN
# 0.0       19276.122751    13394.799469             0.747751  0.143959
# 1.0       20130.399245    10929.938462             1.815041  0.282230
#
#           PAST_ACCIDENTS   OUTCOME
# CHILDREN
# 0.0             0.549165  0.473972
# 1.0             1.285424  0.240708

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['POSTAL_CODE']).mean()
# Out:
# <ipython-input-106-7a6d8a389ae1>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['POSTAL_CODE']).mean()
#                         ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  \
# POSTAL_CODE
# 10238        499608.748127      0.470537           0.696974  0.496542
# 21217        445169.458333      0.492749           0.733333  0.500000
# 32765        505039.851792      0.469049           0.697883  0.496743
# 92101        504413.522727      0.469749           0.683884  0.528926
#
#              CHILDREN  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS      DUIS  \
# POSTAL_CODE
# 10238        0.681556    12178.673061             1.115274  0.200865
# 21217        0.725000    12071.466880             1.116667  0.116667
# 32765        0.702362    10240.108245             2.606678  0.368078
# ...

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['ANNUAL_MILEAGE']).mean()
# Out:
# <ipython-input-107-f511bbb9ebd4>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['ANNUAL_MILEAGE']).mean()
#                            ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  \
# ANNUAL_MILEAGE
# 2000.000000     453428.500000      0.619057           1.000000  1.000000
# 3000.000000     643593.100000      0.463424           0.700000  1.000000
# 4000.000000     563499.037037      0.451973           0.703704  0.888889
# 5000.000000     484098.907692      0.503389           0.769231  0.953846
# 6000.000000     489827.515152      0.493166           0.763636  0.866667
# 7000.000000     506367.608696      0.501123           0.742236  0.850932
# 8000.000000     488474.387792      0.505728           0.741472  0.804309
# ...

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['VEHICLE_TYPE']).mean()
# Out:
# <ipython-input-108-bd2afe3afb58>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['VEHICLE_TYPE']).mean()
#                          ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  \
# VEHICLE_TYPE
# sedan         500116.688544      0.470889           0.696419  0.497427
# sports car    508611.830189      0.460630           0.708595  0.513627
#
#               CHILDREN   POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  \
# VEHICLE_TYPE
# sedan         0.689699  19890.663866    11703.009339             1.481991
# sports car    0.670860  19343.169811    11577.094622             1.501048
#
#                   DUIS  PAST_ACCIDENTS   OUTCOME
# VEHICLE_TYPE
# sedan         0.239840        1.061220  0.312717
# sports car    0.226415        0.958071  0.324948

# %%
#rename categorical column
df.replace({'sedan': '1', 'sports car': '2'},inplace=True)
df['VEHICLE_YEAR'].value_counts()
# Out:
# 2    6967
# 1    3033
# Name: VEHICLE_YEAR, dtype: int64

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['SPEEDING_VIOLATIONS']).mean()
# Out:
# <ipython-input-110-13bfe7a72c3b>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['SPEEDING_VIOLATIONS']).mean()
#                                 ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  \
# SPEEDING_VIOLATIONS
# 0                    499227.393397      0.441484           0.627884  0.384447
# 1                    500017.531736      0.490635           0.736399  0.556347
# 2                    498050.698536      0.490318           0.749354  0.555556
# 3                    509527.534940      0.500006           0.768675  0.619277
# 4                    496500.592453      0.516290           0.801887  0.707547
# 5                    477721.934169      0.506978           0.843260  0.708464
# 6                    538379.202128      0.502907           0.824468  0.707447
# ...

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['DUIS']).mean()
# Out:
# <ipython-input-111-cf6462adfef4>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['DUIS']).mean()
#                  ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  CHILDREN  \
# DUIS
# 0     498342.008992      0.462351           0.677014  0.467972  0.661616
# 1     512928.348299      0.503575           0.775510  0.617687  0.796599
# 2     505565.803625      0.511036           0.809668  0.658610  0.839879
# 3     471552.661765      0.506309           0.823529  0.705882  0.852941
# 4     456536.900000      0.492955           0.700000  0.700000  0.800000
# 5     593530.500000      0.606280           1.000000  0.500000  0.500000
# 6     513675.000000      0.648747           1.000000  1.000000  1.000000
#
#        POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  PAST_ACCIDENTS  \
# ...

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['PAST_ACCIDENTS']).mean()
# Out:
# <ipython-input-112-b61475dd1448>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['PAST_ACCIDENTS']).mean()
#                            ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  \
# PAST_ACCIDENTS
# 0               500885.467586      0.447535           0.641655  0.405444
# 1               508836.114414      0.492340           0.748177  0.545149
# 2               483578.913043      0.492953           0.767210  0.618659
# 3               499098.708978      0.500822           0.767802  0.637771
# 4               510238.185792      0.527597           0.775956  0.721311
# 5               477166.961207      0.519508           0.818966  0.728448
# 6               491316.673611      0.499532           0.826389  0.715278
# ...

# %%
# find the mean rating for seat comfort when grouped by both class and gender
df.groupby(['OUTCOME']).mean()
# Out:
# <ipython-input-113-e27cc791c7bc>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['OUTCOME']).mean()
#                     ID  CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  CHILDREN  \
# OUTCOME
# 0.0      502580.037571      0.497443           0.814621  0.586719  0.761614
# 1.0      496010.836259      0.411126           0.439196  0.304181  0.529205
#
#           POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS      DUIS  \
# OUTCOME
# 0.0      18639.467162    11375.549735             1.924858  0.310179
# 1.0      22549.716885    12401.574221             0.514204  0.083626
#
#          PAST_ACCIDENTS
# OUTCOME
# 0.0            1.403961
# 1.0            0.294287

# %%
#import
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline

# %%
# Define X and y and train test split
X = df.drop(columns = 'OUTCOME')
y = df['OUTCOME']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42, stratify = y)

# %%
# Sélection des colonnes numériques pour la standardisation
numeric_columns = ['AGE', 'GENDER', 'RACE', 'DRIVING_EXPERIENCE', 'EDUCATION', 'INCOME', 'VEHICLE_YEAR', 'VEHICLE_TYPE']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10000 non-null  int64
#  1   AGE                  10000 non-null  object
#  2   GENDER               10000 non-null  object
#  3   RACE                 10000 non-null  object
#  4   DRIVING_EXPERIENCE   10000 non-null  object
#  5   EDUCATION            10000 non-null  object
#  6   INCOME               10000 non-null  object
#  7   CREDIT_SCORE         10000 non-null  float64
#  8   VEHICLE_OWNERSHIP    10000 non-null  float64
#  9   VEHICLE_YEAR         10000 non-null  object
#  10  MARRIED              10000 non-null  float64
#  11  CHILDREN             10000 non-null  float64
#  12  POSTAL_CODE          10000 non-null  int64
#  13  ANNUAL_MILEAGE       10000 non-null  float64
#  14  VEHICLE_TYPE         10000 non-null  object
# ...

# %%
# Standardisation
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
df[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# %%
#import
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# %%
scores = {}

#loop through all combinations of values for all hyperparameters
for d in param_grid['max_depth']:
  for l in param_grid['min_samples_leaf']:
    for s in param_grid['min_samples_split']:
      #fit a model for each combination of hyperparameter values
      model = DecisionTreeClassifier(max_depth=d,
                                     min_samples_leaf=l,
                                     min_samples_split=s)
      model.fit(X_train, y_train)
      score = model.score(X_test, y_test)
      #add the model accuracy to a dictionary with the parameter settings as the
      #keys and the accuracies as the values.
      scores[f'depth {d}, min_samples_leaf {l}, min_samples_split {s} accuracy'] = score.round(6) * 100

#display dictionary of scores
scores
# Out:
# {'depth 1, min_samples_leaf 3, min_samples_split 2 accuracy': 76.6,
#  'depth 1, min_samples_leaf 3, min_samples_split 10 accuracy': 76.6,
#  'depth 1, min_samples_leaf 3, min_samples_split 100 accuracy': 76.6,
#  'depth 1, min_samples_leaf 15, min_samples_split 2 accuracy': 76.6,
#  'depth 1, min_samples_leaf 15, min_samples_split 10 accuracy': 76.6,
#  'depth 1, min_samples_leaf 15, min_samples_split 100 accuracy': 76.6,
#  'depth 1, min_samples_leaf 20, min_samples_split 2 accuracy': 76.6,
#  'depth 1, min_samples_leaf 20, min_samples_split 10 accuracy': 76.6,
#  'depth 1, min_samples_leaf 20, min_samples_split 100 accuracy': 76.6,
#  'depth 2, min_samples_leaf 3, min_samples_split 2 accuracy': 80.08,
#  'depth 2, min_samples_leaf 3, min_samples_split 10 accuracy': 80.08,
#  'depth 2, min_samples_leaf 3, min_samples_split 100 accuracy': 80.08,
#  'depth 2, min_samples_leaf 15, min_samples_split 2 accuracy': 80.08,
# ...

# %%
model = DecisionTreeClassifier()

param_grid = {'max_depth': [1,2,3],
              'min_samples_leaf': [3,15,20],
              'min_samples_split': [2, 10, 100]}

# %%
dt_grid_search = GridSearchCV(model, param_grid)

# %%
dt_grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [1, 2, 3],
#                          'min_samples_leaf': [3, 15, 20],
#                          'min_samples_split': [2, 10, 100]})

# %%
dt_grid_search.best_params_
# Out:
# {'max_depth': 3, 'min_samples_leaf': 3, 'min_samples_split': 2}

# %%
# IMPORT
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
# Instantiate & fit data using PCA
pca = PCA()
pca.fit(df[numeric_columns])
# Out:
# PCA()

# %%
X.shape
# Out:
# (10000, 18)

# %%
# plot the cumulative sum of the percentage of explained variance for each component and those before it.
plt.plot(range(10, 18), pca.explained_variance_ratio_.cumsum(), marker= '.')
plt.xticks(ticks=range(10,18), fontsize=8);

# %%
# Create a transformer pipeline
transformer = make_pipeline(StandardScaler(), PCA(n_components=7))

# %%
logreg = LogisticRegression()
# Create a modeling pipeline
logreg_pipe = make_pipeline(transformer, logreg)
logreg_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('standardscaler', StandardScaler()),
#                                  ('pca', PCA(n_components=7))])),
#                 ('logisticregression', LogisticRegression())])

# %%
print('Training accuracy:', logreg_pipe.score(X_train, y_train))
print('Testing accuracy:', logreg_pipe.score(X_test, y_test))
# Out:
# Training accuracy: 0.8158666666666666
# Testing accuracy: 0.802
